# %% [markdown]
# <a href="https://colab.research.google.com/github/okifarman/MOBILE-UAS/blob/main/Salinan_dari_Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install google-play-scraper

# %%
from google_play_scraper import app

import pandas as pd

import numpy as np

# %%
from google_play_scraper import Sort, reviews_all

result = reviews_all(
    'id.co.bri.brimo',
    sleep_milliseconds=0, # defaults to 0
    lang='id', # defaults to 'en'
    country='id', # defaults to 'us'
    sort=Sort.NEWEST, # defaults to Sort.MOST_RELEVANT , you can use Sort.NEWEST to get newst reviews
)

# %%
from google_play_scraper import Sort, reviews

result, continuation_token = reviews(
    'id.co.bri.brimo',
    lang='id', # defaults to 'en'
    country='id', # defaults to 'us'
    sort=Sort.MOST_RELEVANT, # defaults to Sort.MOST_RELEVANT you can use Sort.NEWEST to get newst reviews
    count=1000, # defaults to 1000
    filter_score_with=None # defaults to None(means all score) Use 1 or 2 or 3 or 4 or 5 to select certain score
)

# %%
df_busu = pd.DataFrame(np.array(result),columns=['review'])

df_busu = df_busu.join(pd.DataFrame(df_busu.pop('review').tolist()))

df_busu.head()
# Out:
#                                reviewId             userName  \
# 0  6dd8d72b-9d2d-404a-9a09-d3904b6dc33f  PERI AZHARI (feinx)
# 1  c86b0f9e-f528-435f-8899-4411090bfde3           bang dudud
# 2  c61993a2-7d55-4ad3-a504-cefab2440edf      Suprapto Prapto
# 3  91c18497-f9ad-4a9c-93e3-2abbf8ef2f3a        Ike Wijayanti
# 4  b6a14fd0-3afd-4d21-9f29-27db976e8b32          Musya Baqoh
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/AD_cM...
# 1  https://play-lh.googleusercontent.com/a-/AD_cM...
# 2  https://play-lh.googleusercontent.com/a/AAcHTt...
# 3  https://play-lh.googleusercontent.com/a/AAcHTt...
# 4  https://play-lh.googleusercontent.com/a/AAcHTt...
#
#                                              content  score  thumbsUpCount  \
# 0  Aplikasi nya lumayan saya suka bisa nge hubung...      2             28
# 1  Parah jaringan kenceng tp loading mulu susah m...      1             29
# ...

# %%
len(df_busu.index)
# Out:
# 1000

# %%
df_busu[['userName', 'score','at', 'content']].head()
# Out:
#               userName  score                  at  \
# 0  PERI AZHARI (feinx)      2 2023-08-10 23:27:33
# 1           bang dudud      1 2023-08-20 03:19:11
# 2      Suprapto Prapto      3 2023-07-05 18:59:47
# 3        Ike Wijayanti      1 2023-07-18 00:41:18
# 4          Musya Baqoh      2 2023-08-15 05:42:41
#
#                                              content
# 0  Aplikasi nya lumayan saya suka bisa nge hubung...
# 1  Parah jaringan kenceng tp loading mulu susah m...
# 2  Halo Brimo, kenapa ada bug: 1. di foto KTP , m...
# 3  Aplikasi super jelek, sering nge bug, mau logi...
# 4  Betul sekali apa yg di bilang teman² di atas,,...

# %%
new_df = df_busu[['userName', 'score','at', 'content']]
sorted_df = new_df.sort_values(by='at', ascending=False)
sorted_df.head()
# Out:
#             userName  score                  at  \
# 162           Random      3 2023-08-21 12:57:15
# 84       Amir Sehati      5 2023-08-21 12:04:27
# 119  Dessy Fajrianty      5 2023-08-21 08:28:37
# 989       Khrisnabie      1 2023-08-21 05:23:02
# 61         Dedy Jaya      1 2023-08-21 04:09:48
#
#                                                content
# 162  Apknya bagus selama saya pakai ga pernah ada k...
# 84   Saya senang karna melalui aplikasi ini Semuany...
# 119  Apaan coba, klo bikin aplikasi itu yg benar, k...
# 989  Kadang Sering terblokir sendiri padahal saya t...
# 61   Bingung gini yaampun. Lupa password gabisa di ...

# %%
my_df = sorted_df[['userName', 'score','at', 'content']]

# %%
my_df.head()
# Out:
#             userName  score                  at  \
# 162           Random      3 2023-08-21 12:57:15
# 84       Amir Sehati      5 2023-08-21 12:04:27
# 119  Dessy Fajrianty      5 2023-08-21 08:28:37
# 989       Khrisnabie      1 2023-08-21 05:23:02
# 61         Dedy Jaya      1 2023-08-21 04:09:48
#
#                                                content
# 162  Apknya bagus selama saya pakai ga pernah ada k...
# 84   Saya senang karna melalui aplikasi ini Semuany...
# 119  Apaan coba, klo bikin aplikasi itu yg benar, k...
# 989  Kadang Sering terblokir sendiri padahal saya t...
# 61   Bingung gini yaampun. Lupa password gabisa di ...

# %%
my_df.to_csv("scrapped_data.csv", index = False)
